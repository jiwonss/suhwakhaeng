# %%
pip install -r requirements.txt
# Out:
# Failed to start the Kernel.
#
# Traceback (most recent call last):
#
#   File "/Users/uhyeon/.vscode/extensions/ms-toolsai.jupyter-2022.3.1000901801/pythonFiles/vscode_datascience_helpers/daemon/daemon_python.py", line 54, in _decorator
#
#     return func(self, *args, **kwargs)
#
#   File "/Users/uhyeon/.vscode/extensions/ms-toolsai.jupyter-2022.3.1000901801/pythonFiles/vscode_datascience_helpers/jupyter_daemon.py", line 108, in m_exec_module_observable
#
#     self._start_notebook(args, cwd, env)
#
#   File "/Users/uhyeon/.vscode/extensions/ms-toolsai.jupyter-2022.3.1000901801/pythonFiles/vscode_datascience_helpers/jupyter_daemon.py", line 154, in _start_notebook
#
#     from notebook import notebookapp as app
#
# ImportError: cannot import name 'notebookapp' from 'notebook' (/Users/uhyeon/.pyenv/versions/3.8.13/lib/python3.8/site-packages/notebook/__init__.py)
#
#
#
# Failed to run jupyter as observable with args notebook --no-browser --notebook-dir="/Users/uhyeon/S10P22C103/backend/diagnosis" --KernelManager.autorestart=False --config=/var/folders/wn/j_35j6516zgcvm_kvsb1snlm0000gn/T/fcc63cd1-f167-4e18-b17f-472a73e81131/jupyter_notebook_config.py --NotebookApp.iopub_data_rate_limit=10000000000.0.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import os, glob
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.models import Model
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.applications.resnet import ResNet101
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet50 import preprocess_input
from sklearn.metrics import  classification_report
import pickle
# Out:
# Failed to start the Kernel.
#
# Traceback (most recent call last):
#
#   File "/Users/uhyeon/.vscode/extensions/ms-toolsai.jupyter-2022.3.1000901801/pythonFiles/vscode_datascience_helpers/daemon/daemon_python.py", line 54, in _decorator
#
#     return func(self, *args, **kwargs)
#
#   File "/Users/uhyeon/.vscode/extensions/ms-toolsai.jupyter-2022.3.1000901801/pythonFiles/vscode_datascience_helpers/jupyter_daemon.py", line 108, in m_exec_module_observable
#
#     self._start_notebook(args, cwd, env)
#
#   File "/Users/uhyeon/.vscode/extensions/ms-toolsai.jupyter-2022.3.1000901801/pythonFiles/vscode_datascience_helpers/jupyter_daemon.py", line 154, in _start_notebook
#
#     from notebook import notebookapp as app
#
# ImportError: cannot import name 'notebookapp' from 'notebook' (/Users/uhyeon/.pyenv/versions/3.8.13/lib/python3.8/site-packages/notebook/__init__.py)
#
#
#
# Failed to run jupyter as observable with args notebook --no-browser --notebook-dir="/Users/uhyeon/S10P22C103/backend/diagnosis" --KernelManager.autorestart=False --config=/var/folders/wn/j_35j6516zgcvm_kvsb1snlm0000gn/T/6dcb54de-3662-43e7-a987-64ccfcfe4d61/jupyter_notebook_config.py --NotebookApp.iopub_data_rate_limit=10000000000.0.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
file_path = ("../input/plantdisease/plantvillage/segmented")

# %%
name_class = os.listdir(file_path)
name_class
label_dict = {label: index for index, label in enumerate(name_class)}
# JSON 파일로 저장
with open('labels.json', 'wb') as f:
    pickle.dump(label_dict, f)
# Out:
# ['Pepper__bell___Bacterial_spot',
#  'Potato___healthy',
#  'Tomato_Leaf_Mold',
#  'Tomato__Tomato_YellowLeaf__Curl_Virus',
#  'Tomato_Bacterial_spot',
#  'Tomato_Septoria_leaf_spot',
#  'Tomato_healthy',
#  'Tomato_Spider_mites_Two_spotted_spider_mite',
#  'Tomato_Early_blight',
#  'Tomato__Target_Spot',
#  'Pepper__bell___healthy',
#  'Potato___Late_blight',
#  'Tomato_Late_blight',
#  'Potato___Early_blight',
#  'Tomato__Tomato_mosaic_virus']

# %%
filepaths = list(glob.glob(file_path+'/**/*.*'))

# %%
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))
filepath = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')
data = pd.concat([filepath, labels], axis=1)
data = data.sample(frac=1).reset_index(drop=True)
data.head(5)
# Out:
#                                             Filepath  \
# 0  ../input/plantdisease/PlantVillage/Tomato_Spid...
# 1  ../input/plantdisease/PlantVillage/Tomato_Spid...
# 2  ../input/plantdisease/PlantVillage/Tomato_Bact...
# 3  ../input/plantdisease/PlantVillage/Tomato_Bact...
# 4  ../input/plantdisease/PlantVillage/Tomato_Late...
#
#                                          Label
# 0  Tomato_Spider_mites_Two_spotted_spider_mite
# 1  Tomato_Spider_mites_Two_spotted_spider_mite
# 2                        Tomato_Bacterial_spot
# 3                        Tomato_Bacterial_spot
# 4                           Tomato_Late_blight

# %%
counts = data.Label.value_counts()
sns.barplot(x=counts.index, y=counts)
plt.xlabel('Type')
plt.xticks(rotation=90);

# %%
train, test = train_test_split(data, test_size=0.25, random_state=42)

# %%
fig, axes = plt.subplots(nrows=5, ncols=3, figsize=(10,8), subplot_kw={'xticks':[],'yticks':[]})
for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(data.Filepath[i]))
    ax.set_title(data.Label[i])
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input,
                                   validation_split=0.2)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
train_gen = train_datagen.flow_from_dataframe(
    dataframe=train,
    x_col='Filepath',
    y_col='Label',
    target_size=(256,256),
    class_mode='categorical',
    batch_size=12,
    shuffle=True,
    seed=42
)
valid_gen = train_datagen.flow_from_dataframe(
    dataframe=train,
    x_col='Filepath',
    y_col='Label',
    target_size=(256,256),
    class_mode='categorical',
    batch_size=12,
    shuffle=False,
    seed=42
)
test_gen = test_datagen.flow_from_dataframe(
    dataframe=test,
    x_col='Filepath',
    y_col='Label',
    target_size=(256,256),
    class_mode='categorical',
    batch_size=12,
    shuffle=False
)
# Out:
# Found 15478 validated image filenames belonging to 15 classes.
# Found 15478 validated image filenames belonging to 15 classes.
# Found 5160 validated image filenames belonging to 15 classes.

# %%
pretrained_model = ResNet101(
    input_shape=(256,256, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)

pretrained_model.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171446536/171446536 [==============================] - 1s 0us/step

# %%
inputs = pretrained_model.input

x = Dense(128, activation='relu')(pretrained_model.output)
x = Dense(128, activation='relu')(x)
x = Dense(128, activation='relu')(x)

outputs = Dense(15, activation='softmax')(x)

model = Model(inputs=inputs, outputs=outputs)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
my_callbacks  = [EarlyStopping(monitor='val_accuracy',
                              min_delta=0,
                              patience=2,
                              mode='auto')]

# %%
history = model.fit(
    train_gen,
    validation_data=valid_gen,
    epochs=6,
    callbacks=my_callbacks
)
# Out:
# Epoch 1/10
# 645/645 [==============================] - 187s 266ms/step - loss: 0.6662 - accuracy: 0.7850 - val_loss: 0.3316 - val_accuracy: 0.8860
# Epoch 2/10
# 645/645 [==============================] - 84s 130ms/step - loss: 0.2972 - accuracy: 0.8982 - val_loss: 0.1700 - val_accuracy: 0.9437
# Epoch 3/10
# 645/645 [==============================] - 84s 130ms/step - loss: 0.2214 - accuracy: 0.9241 - val_loss: 0.1283 - val_accuracy: 0.9581
# Epoch 4/10
# 645/645 [==============================] - 86s 133ms/step - loss: 0.1696 - accuracy: 0.9424 - val_loss: 0.1107 - val_accuracy: 0.9623
# Epoch 5/10
# 645/645 [==============================] - 85s 132ms/step - loss: 0.1416 - accuracy: 0.9515 - val_loss: 0.1011 - val_accuracy: 0.9656
# Epoch 6/10
# 645/645 [==============================] - 84s 130ms/step - loss: 0.1303 - accuracy: 0.9546 - val_loss: 0.1746 - val_accuracy: 0.9415
# Epoch 7/10
# 645/645 [==============================] - 84s 130ms/step - loss: 0.1079 - accuracy: 0.9627 - val_loss: 0.1165 - val_accuracy: 0.9601

# %%
pd.DataFrame(history.history)[['accuracy','val_accuracy']].plot()
plt.title("Accuracy")
plt.show()

pd.DataFrame(history.history)[['loss','val_loss']].plot()
plt.title("Loss")
plt.show()

# %%
results = model.evaluate(test_gen, verbose=0)

print("    Test Loss: {:.5f}".format(results[0]))
print("Test Accuracy: {:.2f}%".format(results[1] * 100))
# Out:
#     Test Loss: 0.35006
# Test Accuracy: 90.54%

# %%
# Predict the label of the test_gen
pred = model.predict(test_gen)
pred = np.argmax(pred,axis=1)

# Map the label
labels = (train_gen.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred = [labels[k] for k in pred]
# Out:
# 215/215 [==============================] - 16s 67ms/step

# %%
y_test = list(test.Label)
print(classification_report(y_test, pred))
# Out:
#                                              precision    recall  f1-score   support
#
#               Pepper__bell___Bacterial_spot       0.93      0.93      0.93       240
#                      Pepper__bell___healthy       0.93      0.99      0.96       399
#                       Potato___Early_blight       0.97      0.96      0.96       236
#                        Potato___Late_blight       0.92      0.94      0.93       250
#                            Potato___healthy       0.91      0.77      0.83        39
#                       Tomato_Bacterial_spot       0.93      0.92      0.93       531
#                         Tomato_Early_blight       0.82      0.77      0.79       273
#                          Tomato_Late_blight       0.92      0.86      0.89       473
#                            Tomato_Leaf_Mold       0.80      0.92      0.86       225
#                   Tomato_Septoria_leaf_spot       0.78      0.95      0.86       451
# Tomato_Spider_mites_Two_spotted_spider_mite       0.91      0.75      0.82       404
#                         Tomato__Target_Spot       0.93      0.72      0.81       335
#       Tomato__Tomato_YellowLeaf__Curl_Virus       0.93      0.99      0.96       801
#                 Tomato__Tomato_mosaic_virus       0.99      0.86      0.92        84
#                              Tomato_healthy       0.96      0.99      0.97       419
#
#                                    accuracy                           0.91      5160
#                                   macro avg       0.91      0.89      0.89      5160
#                                weighted avg       0.91      0.91      0.90      5160

# %%
fig, axes = plt.subplots(nrows=5, ncols=2, figsize=(12, 8),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(test.Filepath.iloc[i]))
    ax.set_title(f"True: {test.Label.iloc[i]}\nPredicted: {pred[i]}")
plt.tight_layout()
plt.show()

# %%
model.save('cnn_final.h5')
