# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from -r requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: seaborn in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from -r requirements.txt (line 2)) (0.13.2)
# Requirement already satisfied: matplotlib in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from -r requirements.txt (line 3)) (3.8.3)
# Requirement already satisfied: pandas in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from -r requirements.txt (line 4)) (1.4.2)
# Requirement already satisfied: numpy in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from -r requirements.txt (line 5)) (1.26.4)
# Requirement already satisfied: tensorflow in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from -r requirements.txt (line 6)) (2.16.1)
# Requirement already satisfied: scikit-learn in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from -r requirements.txt (line 7)) (1.4.1.post1)
# Requirement already satisfied: filelock in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from torch->-r requirements.txt (line 1)) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from torch->-r requirements.txt (line 1)) (4.10.0)
# Requirement already satisfied: sympy in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from torch->-r requirements.txt (line 1)) (1.12)
# Requirement already satisfied: networkx in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from torch->-r requirements.txt (line 1)) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from torch->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: fsspec in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from torch->-r requirements.txt (line 1)) (2024.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (6.3.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from pandas->-r requirements.txt (line 4)) (2022.1)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from tensorflow->-r requirements.txt (line 6)) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (24.3.7)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (56.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (2.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (1.62.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (3.0.5)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (0.31.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn->-r requirements.txt (line 7)) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn->-r requirements.txt (line 7)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn->-r requirements.txt (line 7)) (3.3.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->-r requirements.txt (line 3)) (3.18.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from jinja2->torch->-r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from sympy->torch->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (0.43.0)
# Requirement already satisfied: rich in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (13.7.1)
# Requirement already satisfied: namex in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (0.0.7)
# Requirement already satisfied: dm-tree in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (0.1.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (2.0.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (2021.10.8)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (3.5.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (2.0.2)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from markdown>=2.6.8->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (7.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow->-r requirements.txt (line 6)) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os, glob
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.models import Model
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.applications.resnet import ResNet101
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet50 import preprocess_input
from sklearn.metrics import  classification_report
import pickle

# %%
file_path = ("../input/color")

# %%
# def delete_photos_with_keyword(directory, keyword):
#     # 주어진 디렉토리 내의 파일 목록을 가져옴
#     files = os.listdir(directory)
    
#     # 파일 목록을 순회하면서 특정 키워드를 포함하는 파일을 삭제
#     for file_name in files:
#         if keyword in file_name:
#             try:
#                 file_path = os.path.join(directory, file_name)
#                 os.remove(file_path)
#                 print(f"Deleted: {file_path}")
#             except Exception as e:
#                 print(f"Failed to delete: {file_path}. Error: {e}")

# # 사용 예시
# directory_path = "../input/color/Tomato___Tomato_Yellow_Leaf_Curl_Virus"
# keyword_to_delete = "UF.GRC_YLCV_Lab"
# delete_photos_with_keyword(directory_path, keyword_to_delete)

# %%
name_class = os.listdir(file_path)
name_class
label_dict = {label: index for index, label in enumerate(name_class)}

# %%
filepaths = list(glob.glob(file_path+'/**/*.*'))

# %%
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))
filepath = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')
data = pd.concat([filepath, labels], axis=1)
data = data.sample(frac=1).reset_index(drop=True)
data.head(5)
# Out:
#                                             Filepath                  Label
# 0  ../input/color\Potato___Early_blight\f8b57e69-...  Potato___Early_blight
# 1  ../input/color\Tomato___healthy\48af8eac-8662-...       Tomato___healthy
# 2  ../input/color\Potato___Late_blight\6fc1834e-7...   Potato___Late_blight
# 3  ../input/color\Potato___Late_blight\7b38a18a-6...   Potato___Late_blight
# 4  ../input/color\Tomato___Early_blight\22b8de0e-...  Tomato___Early_blight

# %%
counts = data.Label.value_counts()
sns.barplot(x=counts.index, y=counts)
plt.xlabel('Type')
plt.xticks(rotation=90);

# %%
train, test = train_test_split(data, test_size=0.25, shuffle=False)

# %%
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(10,8), subplot_kw={'xticks':[],'yticks':[]})
for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(data.Filepath[i]))
    ax.set_title(data.Label[i])
plt.tight_layout()
plt.show()
# Out:
# Potato___Early_blight
# Tomato___healthy
# Potato___Late_blight
# Potato___Late_blight
# Tomato___Early_blight
# Tomato___Early_blight
# Tomato___Late_blight
# Tomato___Late_blight

# %%
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input,
                                   validation_split=0.2)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
train_gen = train_datagen.flow_from_dataframe(
    dataframe=train,
    x_col='Filepath',
    y_col='Label',
    target_size=(256,256),
    class_mode='categorical',
    batch_size=8,
    shuffle=False,
    seed=42
)
valid_gen = train_datagen.flow_from_dataframe(
    dataframe=train,
    x_col='Filepath',
    y_col='Label',
    target_size=(256,256),
    class_mode='categorical',
    batch_size=8,
    shuffle=False,
    seed=42
)
test_gen = test_datagen.flow_from_dataframe(
    dataframe=test,
    x_col='Filepath',
    y_col='Label',
    target_size=(256,256),
    class_mode='categorical',
    batch_size=8,
    shuffle=False
)
# Out:
# Found 7073 validated image filenames belonging to 8 classes.
# Found 7073 validated image filenames belonging to 8 classes.
# Found 2358 validated image filenames belonging to 8 classes.

# %%
pretrained_model = ResNet101(
    input_shape=(256,256, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)

pretrained_model.trainable = False

# %%
inputs = pretrained_model.input

x = Dense(128, activation='relu')(pretrained_model.output)
x = Dense(128, activation='relu')(x)
x = Dense(128, activation='relu')(x)

outputs = Dense(8, activation='softmax')(x)

model = Model(inputs=inputs, outputs=outputs)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
my_callbacks  = [EarlyStopping(monitor='val_accuracy',
                              min_delta=0,
                              patience=2,
                              mode='auto')]

# %%
history = model.fit(
    train_gen,
    validation_data=valid_gen,
    epochs=5,
    callbacks=my_callbacks
)
# Out:
# Epoch 1/5
# C:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 383/885 ━━━━━━━━━━━━━━━━━━━━ 4:08 496ms/step - accuracy: 0.7491 - loss: 0.6948
# ---------------------------------------------------------
# KeyboardInterrupt       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 history = model.fit(
#       2     train_gen,
#       3     validation_data=valid_gen,
#       4     epochs=5,
#       5     callbacks=my_callbacks
#       6 )
#
# File C:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages\keras\src\utils\traceback_utils.py:118, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     116 filtered_tb = None
#     117 try:
# --> 118     return fn(*args, **kwargs)
#     119 except Exception as e:
#     120     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File C:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages\keras\src\backend\tensorflow\trainer.py:323, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     321 for step, iterator in epoch_iterator.enumerate_epoch():
#     322     callbacks.on_train_batch_begin(step)
# --> 323     logs = self.train_function(iterator)
#     324     callbacks.on_train_batch_end(
#     325         step, self._pythonify_logs(logs)
#     326     )
#     327     if self.stop_training:
#
# File C:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File C:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File C:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File C:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File C:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File C:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File C:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File C:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\eager\context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File C:\users\uhyeon\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
pd.DataFrame(history.history)[['accuracy','val_accuracy']].plot()
plt.title("Accuracy")
plt.show()

pd.DataFrame(history.history)[['loss','val_loss']].plot()
plt.title("Loss")
plt.show()

# %%
labels = {}
for class_name, class_index in train_gen.class_indices.items():
    labels[class_name] = class_index
with open('labels.json', 'wb') as f:
    pickle.dump(labels, f)

# %%
results = model.evaluate(test_gen, verbose=0)

print("    Test Loss: {:.5f}".format(results[0]))
print("Test Accuracy: {:.2f}%".format(results[1] * 100))

# %%
# Predict the label of the test_gen
pred = model.predict(test_gen)
pred = np.argmax(pred,axis=1)

# Map the label
labels = (train_gen.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred = [labels[k] for k in pred]

# %%
y_test = list(test.Label)
print(classification_report(y_test, pred))

# %%
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(10,8),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(test.Filepath.iloc[i]))
    ax.set_title(f"True: {test.Label.iloc[i]}\nPredicted: {pred[i]}")
plt.tight_layout()
plt.show()

# %%
model.save('model.h5')
